# %%
import pandas as pd

# %%
metadata = pd.read_csv("/Users/karthikramesh/src/HCoV-19-Genomics/metadata.csv")
metadata
# Out:
#                     ID gb_accession gisaid_accession collection_date  \
# 0               MG0987     MT598172   EPI_ISL_416457      2020-03-18
# 1             PC00101P     MT192765   EPI_ISL_414648      2020-03-11
# 2      SEARCH-0007-SAN     MT598171   EPI_ISL_429990      2020-03-21
# 3      SEARCH-0016-SAN     MT598173   EPI_ISL_430016      2020-03-24
# 4      SEARCH-0017-SAN     MT598174   EPI_ISL_429991      2020-03-24
# ...                ...          ...              ...             ...
# 41588    SEARCH-113411          NaN              NaN      2021-09-27
# 41589    SEARCH-113412          NaN              NaN      2021-09-27
# 41590    SEARCH-113413          NaN              NaN      2021-09-28
# 41591    SEARCH-113414          NaN              NaN      2021-09-28
# 41592    SEARCH-113415          NaN              NaN      2021-09-28
#
#                                                 location  \
# 0                 North America/USA/California/San Diego
# ...
